# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression, ElasticNet
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import xgboost as xgb
import warnings
warnings.filterwarnings("ignore")
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
# Load data
df = pd.read_csv(r"e:/Nieuw dataset/Joined trends/joined_trend_sales_All1.csv")
df["Periode"] = pd.to_datetime(df["Periode"], format="%Y/%m")
df = df.sort_values("Periode").reset_index(drop=True)

# Create lag features and date parts
for lag in range(1, 7):
    df[f"TVV_Lag{lag}"] = df["Totaal_verkochte_wegvoertuigen"].shift(lag)
df_lagged = df.dropna().reset_index(drop=True)
df_lagged['year'] = df_lagged['Periode'].dt.year
df_lagged['month'] = df_lagged['Periode'].dt.month
df_lagged['quarter'] = df_lagged['Periode'].dt.quarter
cols = [col for col in df_lagged.columns if col != 'Totaal_verkochte_wegvoertuigen'] + ['Totaal_verkochte_wegvoertuigen']
df_lagged = df_lagged[cols]

# %%
# Define lag and time features to add to all subsets
lag_time_features = ['TVV_Lag1', 'TVV_Lag2', 'TVV_Lag3', 'TVV_Lag4', 'TVV_Lag5', 'TVV_Lag6', 'year', 'month', 'quarter']

# Redefine feature sets with those always included
feature_sets = {
    'Lag Only': lag_time_features,
    'Keywords + Lag': lag_time_features + ['thuis opladen', 'elektrische auto', 'hybride elektrisch'],
    'Bijtelling + Lag': lag_time_features + ['Bijtelling (%)'],
    'Confidence + Lag': lag_time_features + ['Consumentenvertrouwen', 'Economisch klimaat', 'Koopbereidheid', 'Grote aankopen'],
    'Fuel + Lag': lag_time_features + [
        'BenzineEuro95_1_first', 'BenzineEuro95_1_last', 'BenzineEuro95_1_min',
        'BenzineEuro95_1_max', 'BenzineEuro95_1_mean',
        'Diesel_2_first', 'Diesel_2_last', 'Diesel_2_min', 'Diesel_2_max', 'Diesel_2_mean'
    ]
}

# Add full feature set: everything except target and 'Periode'
all_features = [
    'thuis opladen', 'elektrische auto', 'hybride elektrisch',
    'Bijtelling (%)', 'Consumentenvertrouwen', 'Economisch klimaat',
    'Koopbereidheid', 'Grote aankopen',
    'BenzineEuro95_1_first', 'BenzineEuro95_1_last', 'BenzineEuro95_1_min',
    'BenzineEuro95_1_max', 'BenzineEuro95_1_mean',
    'Diesel_2_first', 'Diesel_2_last', 'Diesel_2_min', 'Diesel_2_max', 'Diesel_2_mean'
] + lag_time_features

feature_sets['All Features'] = all_features

# %% [markdown]
#  Aangepaste versie mét rolling test forecast

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

def strict_expanding_window_validation(
    df, features, target_col, model_fn,
    forecast_horizon=3
):
    n = len(df)
    test_start = int(n * 0.85)
    val_start = int(n * 0.75)

    X = df[features].values
    y = df[target_col].values

    # === VALIDATIE (expanding window binnen trainval) ===
    val_preds, val_actuals, val_dates = [], [], []
    for i in range(val_start, test_start - forecast_horizon + 1):
        X_train = X[:i]
        y_train = y[:i]
        X_val = X[i:i+forecast_horizon]
        y_val = y[i:i+forecast_horizon]

        model = model_fn()
        model.fit(X_train, y_train)
        preds = model.predict(X_val)

        val_preds.extend(preds)
        val_actuals.extend(y_val)
        val_dates.extend(df.iloc[i:i+forecast_horizon]['Periode'].values)

    # === TEST (rolling window vanaf test_start) ===
    test_preds, test_actuals, test_dates = [], [], []
    for i in range(test_start, n - forecast_horizon + 1):
        X_train = X[:i]
        y_train = y[:i]
        X_test = X[i:i+forecast_horizon]
        y_test = y[i:i+forecast_horizon]

        model = model_fn()
        model.fit(X_train, y_train)
        preds = model.predict(X_test)

        test_preds.extend(preds)
        test_actuals.extend(y_test)
        test_dates.extend(df.iloc[i:i+forecast_horizon]['Periode'].values)

    # === Scores ===
    val_mae = mean_absolute_error(val_actuals, val_preds)
    val_rmse = np.sqrt(mean_squared_error(val_actuals, val_preds))
    val_r2 = r2_score(val_actuals, val_preds)
    val_mape = mean_absolute_percentage_error(val_actuals, val_preds)

    test_mae = mean_absolute_error(test_actuals, test_preds)
    test_rmse = np.sqrt(mean_squared_error(test_actuals, test_preds))
    test_r2 = r2_score(test_actuals, test_preds)
    test_mape = mean_absolute_percentage_error(test_actuals, test_preds)

    return {
        "val_mae": val_mae,
        "val_rmse": val_rmse,
        "val_r2": val_r2,
        "val_mape": val_mape,
        "val_preds": np.array(val_preds),
        "val_actuals": np.array(val_actuals),
        "val_dates": np.array(val_dates),
        "test_mae": test_mae,
        "test_rmse": test_rmse,
        "test_r2": test_r2,
        "test_mape": test_mape,
        "test_preds": np.array(test_preds),
        "test_actuals": np.array(test_actuals),
        "test_dates": np.array(test_dates)
    }

# %% [markdown]
# ### Explanation of the Data Split and Expanding Window Validation
#
# This function implements a strict time series split with expanding window validation and a rolling test forecast. The data is divided as follows:
#
# - **Training set:** The first 75% of the data (from the start up to 75% of the timeline).
# - **Validation set:** The next 10% of the data (from 75% to 85% of the timeline). Validation is performed using an expanding window: for each step, the model is trained on all data up to that point and validated on the next `forecast_horizon` periods.
# - **Test set:** The final 15% of the data (from 85% to 100% of the timeline). Testing is also done with a rolling window: for each step, the model is trained on all data up to that point and tested on the next `forecast_horizon` periods.
#
# **Key points:**
# - At every step, only past data is used to predict future values, preventing lookahead bias and data leakage.
# - The validation and test predictions are made in a way that simulates real-world forecasting, where only information up to the prediction date is available.
# - This approach is robust for time series forecasting and ensures that model evaluation is realistic and fair.

# %%
import matplotlib.pyplot as plt

# Bepaal de indexen voor splits (zelfde logica als in je validatiefunctie)
n = len(df_lagged)
train_end = int(n * 0.75)
val_end = int(n * 0.85)
test_end = n

train_dates = df_lagged['Periode'].iloc[:train_end]
val_dates = df_lagged['Periode'].iloc[train_end:val_end]
test_dates = df_lagged['Periode'].iloc[val_end:test_end]

plt.figure(figsize=(12, 2))
plt.plot(train_dates, [1]*len(train_dates), '|', color='blue', markersize=20, label='Train')
plt.plot(val_dates, [2]*len(val_dates), '|', color='orange', markersize=20, label='Validation')
plt.plot(test_dates, [3]*len(test_dates), '|', color='green', markersize=20, label='Test')

plt.yticks([1, 2, 3], ['Train', 'Validation', 'Test'])
plt.xlabel('Date')
plt.title('Train/Validation/Test splits over tijd')
plt.legend()
plt.tight_layout()
plt.show()
print("Train months:", train_dates.min().strftime("%Y-%m"), "->", train_dates.max().strftime("%Y-%m"), f"({len(train_dates)} maanden)")
print("Validation months:", val_dates.min().strftime("%Y-%m"), "->", val_dates.max().strftime("%Y-%m"), f"({len(val_dates)} maanden)")
print("Test months:", test_dates.min().strftime("%Y-%m"), "->", test_dates.max().strftime("%Y-%m"), f"({len(test_dates)} maanden)")
# Out:
# Train months: 2007-07 -> 2020-08 (158 maanden)
# Validation months: 2020-09 -> 2022-05 (21 maanden)
# Test months: 2022-06 -> 2025-01 (32 maanden)

# %%
print("Train dates:")
print(df_lagged['Periode'].iloc[:train_end].min(), "->", df_lagged['Periode'].iloc[:train_end].max())
print("Aantal train:", train_end, f"({train_end/len(df_lagged)*100:.1f}%)")

print("\nValidation dates:")
print(df_lagged['Periode'].iloc[train_end:val_end].min(), "->", df_lagged['Periode'].iloc[train_end:val_end].max())
print("Aantal validatie:", val_end - train_end, f"({(val_end-train_end)/len(df_lagged)*100:.1f}%)")

print("\nTest dates:")
print(df_lagged['Periode'].iloc[val_end:test_end].min(), "->", df_lagged['Periode'].iloc[val_end:test_end].max())
print("Aantal test:", test_end - val_end, f"({(test_end-val_end)/len(df_lagged)*100:.1f}%)")
# Out:
# Train dates:
# 2007-07-01 00:00:00 -> 2020-08-01 00:00:00
# Aantal train: 158 (74.9%)
#
# Validation dates:
# 2020-09-01 00:00:00 -> 2022-05-01 00:00:00
# Aantal validatie: 21 (10.0%)
#
# Test dates:
# 2022-06-01 00:00:00 -> 2025-01-01 00:00:00
# Aantal test: 32 (15.2%)

# %% [markdown]
# #### Nulmodel

# %%
from sklearn.metrics import mean_absolute_percentage_error
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Haal de validatiedatums op uit je model-validatie (gebruik dezelfde split!)
val_dates = strict_expanding_window_validation(
    df_lagged, feature_sets['Lag Only'], 'Totaal_verkochte_wegvoertuigen',
    lambda: xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, 
                             learning_rate=0.1, max_depth=3, random_state=42, eval_metric="rmse"),
    forecast_horizon=3
)['val_dates']
val_dates = pd.to_datetime(val_dates)

results = {}
for label, features in feature_sets.items():
    if label != 'Lag Only':
        continue

    val_preds = df_lagged['TVV_Lag1'].values
    val_actuals = df_lagged['Totaal_verkochte_wegvoertuigen'].values
    validation_dates = pd.to_datetime(df_lagged['Periode'].values)

    # Filter alleen de datums die in de validatieset zitten
    mask = validation_dates.isin(val_dates)
    print(f"Mask sum: {mask.sum()} (should be >0)")
    val_preds = val_preds[mask]
    val_actuals = val_actuals[mask]
    validation_dates = validation_dates[mask]

    results[label] = pd.DataFrame({
        'date': validation_dates,
        'actual': val_actuals,
        'pred': val_preds
    }).drop_duplicates(subset='date', keep='first')

    # MAPE voor Random Walk (Lag Only) nulmodel op validatieset
    mape_lag = mean_absolute_percentage_error(val_actuals, val_preds)
    print(f"Random Walk (Lag Only) nulmodel MAPE: {mape_lag:.4f}")

df_lag = results['Lag Only'][['date', 'actual', 'pred']].rename(columns={'pred': 'pred_lag'})

plt.figure(figsize=(12, 5))
plt.plot(df_lag['date'], df_lag['actual'], label='Actual', color='black')
plt.plot(df_lag['date'], df_lag['pred_lag'], label='Random Walk (Lag Only)', color='orange')
plt.title('Random Walk Null Model: Lag Only')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Mask sum: 21 (should be >0)
# Random Walk (Lag Only) nulmodel MAPE: 0.3480

# %% [markdown]
# ### Baseline

# %% [markdown]
# #### XGBoost

# %%
results = {}
for label, features in feature_sets.items():
    if label not in ['Lag Only', 'All Features']:
        continue  # Sla andere feature sets over

    res = strict_expanding_window_validation(
        df_lagged, features, 'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100,
                                 learning_rate=0.1, max_depth=3, random_state=42, eval_metric="rmse"),
        forecast_horizon=3
    )
    print(f"XGBoost ({label}): MAPE={res['val_mape']:.4f}, MAE={res['val_mae']:.2f}, RMSE={res['val_rmse']:.2f}, R²={res['val_r2']:.3f}")

    # Sla resultaten op in dictionary
    results[label] = {
        'date': pd.to_datetime(res['val_dates']),
        'actual': res['val_actuals'],
        'pred': res['val_preds']
    }

# Maak DataFrames van de resultaten
df_all = pd.DataFrame(results['All Features']).drop_duplicates(subset='date', keep='first')
df_lag = pd.DataFrame(results['Lag Only']).drop_duplicates(subset='date', keep='first')

# Merge op datum
df_merged = pd.merge(
    df_all[['date', 'actual', 'pred']].rename(columns={'pred': 'pred_all'}),
    df_lag[['date', 'pred']].rename(columns={'pred': 'pred_lag'}),
    on='date',
    how='inner'
)

plt.rcParams.update({'legend.fontsize': 14, 'axes.labelsize': 16, 'axes.titlesize': 18, 'xtick.labelsize': 12, 'ytick.labelsize': 12})
plt.figure(figsize=(12, 5))
plt.plot(df_merged['date'], df_merged['actual'], label='Actual', color='black')
plt.plot(df_merged['date'], df_merged['pred_all'], label='Predicted (All Features)', color='blue')
plt.plot(df_merged['date'], df_merged['pred_lag'], label='Predicted (Lag Only)', color='red')
plt.title('XGBoost: All Features vs Lag Only')
plt.xlabel('Date')
plt.ylabel('Totaal verkochte wegvoertuigen')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# XGBoost (Lag Only): MAPE=0.2111, MAE=3138.81, RMSE=4217.81, R²=0.578
# XGBoost (All Features): MAPE=0.3174, MAE=4282.95, RMSE=6666.06, R²=-0.054

# %% [markdown]
# #### Arimax

# %%
from sklearn.preprocessing import StandardScaler

# ARIMAX wrapper met standaardisatie
class ARIMAXWrapper:
    def __init__(self, order=(1, 1, 1)):
        self.order = order
        self.model_fit = None
        self.scaler = None
        
    def fit(self, X, y):
        from statsmodels.tsa.statespace.sarimax import SARIMAX
        self.scaler = StandardScaler()
        X_scaled = self.scaler.fit_transform(X)
        model = SARIMAX(y, exog=X_scaled, order=self.order,
                        enforce_stationarity=False, enforce_invertibility=False)
        self.model_fit = model.fit(disp=False)
        return self
        
    def predict(self, X):
        if self.model_fit is None or self.scaler is None:
            raise ValueError("Model not fitted yet")
        X_scaled = self.scaler.transform(X)
        return self.model_fit.forecast(steps=len(X), exog=X_scaled)

arimax_results = {}

# Voer ARIMAX uit voor beide feature sets
for label, features in feature_sets.items():
    if label not in ['Lag Only', 'All Features']:
        continue

    res = strict_expanding_window_validation(
        df_lagged, features, 'Totaal_verkochte_wegvoertuigen',
        lambda: ARIMAXWrapper(order=(1, 1, 1)),
        forecast_horizon=3
    )

    print(f"ARIMAX ({label}): MAPE={res['val_mape']:.4f}, MAE={res['val_mae']:.2f}, RMSE={res['val_rmse']:.2f}, R²={res['val_r2']:.3f}")

    # Sla resultaten op
    arimax_results[label] = {
        'date': pd.to_datetime(res['val_dates']),
        'actual': res['val_actuals'],
        'pred': res['val_preds']
    }

# Maak DataFrames en merge net als bij XGBoost
df_arimax_all = pd.DataFrame(arimax_results['All Features']).drop_duplicates(subset='date', keep='first')
df_arimax_lag = pd.DataFrame(arimax_results['Lag Only']).drop_duplicates(subset='date', keep='first')

df_arimax_merged = pd.merge(
    df_arimax_all[['date', 'actual', 'pred']].rename(columns={'pred': 'pred_all'}),
    df_arimax_lag[['date', 'pred']].rename(columns={'pred': 'pred_lag'}),
    on='date',
    how='inner'
)

# Plot vergelijkende ARIMAX-grafiek
plt.rcParams.update({'legend.fontsize': 14, 'axes.labelsize': 16, 'axes.titlesize': 18, 'xtick.labelsize': 12, 'ytick.labelsize': 12})
plt.figure(figsize=(12, 5))
plt.plot(df_arimax_merged['date'], df_arimax_merged['actual'], label='Actual', color='black')
plt.plot(df_arimax_merged['date'], df_arimax_merged['pred_all'], label='Predicted (All Features)', color='blue')
plt.plot(df_arimax_merged['date'], df_arimax_merged['pred_lag'], label='Predicted (Lag Only)', color='red')
plt.title('ARIMAX: All Features vs Lag Only')
plt.xlabel('Date')
plt.ylabel('Totaal verkochte wegvoertuigen')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ARIMAX (Lag Only): MAPE=0.5708, MAE=7854.58, RMSE=11046.13, R²=-1.895
# ARIMAX (All Features): MAPE=0.5690, MAE=7596.93, RMSE=12042.74, R²=-2.441

# %% [markdown]
# Sarimax extra edit

# %%
# Define your top_features list, e.g.:
top_features = [
    'thuis opladen', 'elektrische auto', 'hybride elektrisch',
    'Bijtelling (%)', 'Consumentenvertrouwen', 'Economisch klimaat',
    'Koopbereidheid', 'Grote aankopen',
    'BenzineEuro95_1_first', 'BenzineEuro95_1_last', 'BenzineEuro95_1_min',
    'BenzineEuro95_1_max', 'BenzineEuro95_1_mean',
    'Diesel_2_first', 'Diesel_2_last', 'Diesel_2_min', 'Diesel_2_max', 'Diesel_2_mean'
]

def test_single_feature_model(features):
    res = strict_expanding_window_validation(
        df_lagged, features, 'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100,
                                 learning_rate=0.1, max_depth=3, random_state=42, eval_metric="rmse"),
        forecast_horizon=3
    )
    print(f"Feature(s): {features} | MAPE={res['val_mape']:.4f}, MAE={res['val_mae']:.2f}, RMSE={res['val_rmse']:.2f}, R²={res['val_r2']:.3f}")

for f in top_features:
    test_single_feature_model([f])

# %%
# Define your top_features list, e.g.:
top_features = [
    'thuis opladen', 'elektrische auto', 'hybride elektrisch',
    'Bijtelling (%)', 'Consumentenvertrouwen', 'Economisch klimaat',
    'Koopbereidheid', 'Grote aankopen',
    'BenzineEuro95_1_first', 'BenzineEuro95_1_last', 'BenzineEuro95_1_min',
    'BenzineEuro95_1_max', 'BenzineEuro95_1_mean',
    'Diesel_2_first', 'Diesel_2_last', 'Diesel_2_min', 'Diesel_2_max', 'Diesel_2_mean'
]

def test_single_feature_model(features):
    res = strict_expanding_window_validation(
        df_lagged, features, 'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100,
                                 learning_rate=0.1, max_depth=3, random_state=42, eval_metric="rmse"),
        forecast_horizon=3
    )
    print(f"Feature(s): {features} | MAPE={res['val_mape']:.4f}, MAE={res['val_mae']:.2f}, RMSE={res['val_rmse']:.2f}, R²={res['val_r2']:.3f}")

for f in top_features:
    test_single_feature_model([f])
# Out:
# Feature(s): ['thuis opladen'] | MAPE=0.4714, MAE=8243.85, RMSE=10999.33, R²=-1.871
# Feature(s): ['elektrische auto'] | MAPE=0.3356, MAE=5268.34, RMSE=7688.45, R²=-0.403
# Feature(s): ['hybride elektrisch'] | MAPE=0.2340, MAE=4461.25, RMSE=7637.72, R²=-0.384
# Feature(s): ['Bijtelling (%)'] | MAPE=0.3806, MAE=6668.47, RMSE=9421.36, R²=-1.106
# Feature(s): ['Consumentenvertrouwen'] | MAPE=0.8375, MAE=13376.84, RMSE=15068.49, R²=-4.388
# Feature(s): ['Economisch klimaat'] | MAPE=0.7933, MAE=12397.02, RMSE=13838.24, R²=-3.544
# Feature(s): ['Koopbereidheid'] | MAPE=0.8012, MAE=12821.97, RMSE=14696.41, R²=-4.125
# Feature(s): ['Grote aankopen'] | MAPE=0.8416, MAE=13234.04, RMSE=14857.72, R²=-4.238
# Feature(s): ['BenzineEuro95_1_first'] | MAPE=0.6826, MAE=10391.43, RMSE=12522.52, R²=-2.721
# Feature(s): ['BenzineEuro95_1_last'] | MAPE=0.5384, MAE=8101.20, RMSE=10887.96, R²=-1.813
# Feature(s): ['BenzineEuro95_1_min'] | MAPE=0.5798, MAE=8804.15, RMSE=11212.39, R²=-1.983
# Feature(s): ['BenzineEuro95_1_max'] | MAPE=0.5882, MAE=8811.77, RMSE=11053.62, R²=-1.899
# Feature(s): ['BenzineEuro95_1_mean'] | MAPE=0.5849, MAE=9019.41, RMSE=11709.89, R²=-2.254
# Feature(s): ['Diesel_2_first'] | MAPE=0.6727, MAE=10435.23, RMSE=12619.44, R²=-2.779
# Feature(s): ['Diesel_2_last'] | MAPE=0.6488, MAE=9960.87, RMSE=12331.71, R²=-2.608
# Feature(s): ['Diesel_2_min'] | MAPE=0.6959, MAE=10937.09, RMSE=13192.32, R²=-3.129
# Feature(s): ['Diesel_2_max'] | MAPE=0.6462, MAE=9985.19, RMSE=12349.62, R²=-2.619
# Feature(s): ['Diesel_2_mean'] | MAPE=0.7114, MAE=11254.98, RMSE=13789.55, R²=-3.512

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

# === ARIMAX Wrapper ===
class ARIMAXWrapper:
    def __init__(self, order=(1, 1, 1), seasonal_order=(0, 1, 1, 12)):
        self.order = order
        self.seasonal_order = seasonal_order
        self.model_fit = None
        self.scaler = None

    def fit(self, X, y):
        self.scaler = StandardScaler()
        X_scaled = self.scaler.fit_transform(X)

        model = SARIMAX(
            endog=y,
            exog=X_scaled,
            order=self.order,
            seasonal_order=self.seasonal_order,
            enforce_stationarity=False,
            enforce_invertibility=False
        )
        self.model_fit = model.fit(disp=False)
        return self

    def predict(self, X, return_conf_int=False):
        if self.model_fit is None or self.scaler is None:
            raise ValueError("Model not fitted yet")

        X_scaled = self.scaler.transform(X)
        forecast = self.model_fit.get_forecast(steps=len(X), exog=X_scaled)

        if return_conf_int:
            conf_int = forecast.conf_int(alpha=0.05)
            return forecast.predicted_mean, conf_int
        else:
            return forecast.predicted_mean


# === Expanding window validation (Validation only) ===
def strict_expanding_window_validation(
    df, features, target_col, model_fn, forecast_horizon=3, return_ci=False
):
    n = len(df)
    val_start = int(n * 0.75)
    test_start = int(n * 0.85)

    X = df[features].values
    y = df[target_col].values

    val_preds, val_actuals, val_dates = [], [], []
    val_ci_lower, val_ci_upper = [], []

    for i in range(val_start, test_start - forecast_horizon + 1):
        X_train = X[:i]
        y_train = y[:i]
        X_val = X[i:i + forecast_horizon]
        y_val = y[i:i + forecast_horizon]

        model = model_fn()
        model.fit(X_train, y_train)

        if return_ci:
            preds, conf = model.predict(X_val, return_conf_int=True)
            val_ci_lower.extend(conf[:, 0])
            val_ci_upper.extend(conf[:, 1])
        else:
            preds = model.predict(X_val)

        val_preds.append(preds[0])
        val_actuals.append(y_val[0])
        val_dates.append(df.iloc[i]['Periode'])
        if return_ci:
            val_ci_lower.append(conf[0, 0])
            val_ci_upper.append(conf[0, 1])

    result = {
        "val_mae": mean_absolute_error(val_actuals, val_preds),
        "val_rmse": np.sqrt(mean_squared_error(val_actuals, val_preds)),
        "val_r2": r2_score(val_actuals, val_preds),
        "val_mape": mean_absolute_percentage_error(val_actuals, val_preds),
        "val_preds": np.array(val_preds),
        "val_actuals": np.array(val_actuals),
        "val_dates": np.array(val_dates)
    }

    if return_ci:
        result["val_ci_lower"] = np.array(val_ci_lower)
        result["val_ci_upper"] = np.array(val_ci_upper)

    return result

top_features = ['hybride elektrisch', 'elektrische auto', 'Bijtelling (%)']

res = strict_expanding_window_validation(
    df_lagged,
    features=top_features,
    target_col='Totaal_verkochte_wegvoertuigen',
    model_fn=lambda: ARIMAXWrapper(order=(1, 1, 1), seasonal_order=(0, 1, 1, 12)),
    forecast_horizon=3,
    return_ci=True
)

print("Validation Results:")
print(f"MAPE: {res['val_mape']:.4f}")
print(f"MAE : {res['val_mae']:.2f}")
print(f"RMSE: {res['val_rmse']:.2f}")
print(f"R²  : {res['val_r2']:.3f}")
# Out:
# Validation Results:
# MAPE: 0.1894
# MAE : 3016.58
# RMSE: 3980.00
# R²  : 0.627

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(res['val_dates'], res['val_actuals'], label='Werkelijk', color='black')
plt.plot(res['val_dates'], res['val_preds'], label='Voorspelling', color='blue')

# Zorg dat alle arrays dezelfde lengte hebben voor fill_between
if 'val_ci_lower' in res and 'val_ci_upper' in res:
    min_len = min(len(res['val_dates']), len(res['val_ci_lower']), len(res['val_ci_upper']))
    plt.fill_between(
        res['val_dates'][:min_len],
        res['val_ci_lower'][:min_len],
        res['val_ci_upper'][:min_len],
        color='blue', alpha=0.2, label='95% CI'
    )

plt.title('SARIMAX Voorspelling met 95% betrouwbaarheidsinterval (Validatie)')
plt.xlabel('Datum')
plt.ylabel('Totaal verkochte voertuigen')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(res['val_dates'], res['val_actuals'], label='Werkelijk', color='black')
plt.plot(res['val_dates'], res['val_preds'], label='Voorspelling', color='blue')

if 'val_ci_lower' in res and 'val_ci_upper' in res:
    plt.fill_between(res['val_dates'], res['val_ci_lower'], res['val_ci_upper'],
                     color='blue', alpha=0.2, label='95% CI')

plt.title('SARIMAX Voorspelling met 95% betrouwbaarheidsinterval (Validatie)')
plt.xlabel('Datum')
plt.ylabel('Totaal verkochte voertuigen')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Fine tune XGBoost

# %% [markdown]
# > Iteratie 1: max_depth

# %%
for max_depth in [1, 2, 3, 5, 7, 9]:
    print(f"\nTesting max_depth={max_depth}")
    res = strict_expanding_window_validation(
        df_lagged, feature_sets['All Features'], 'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(
            objective='reg:squarederror',
            n_estimators=100,
            learning_rate=0.1,
            max_depth=max_depth,
            subsample=1.0,
            min_child_weight=1,
            colsample_bytree=1.0,
            random_state=42,
            eval_metric="rmse"
        ),
        forecast_horizon=3
    )
    print(f"max_depth={max_depth}: MAPE={res['val_mape']:.4f}, MAE={res['val_mae']:.2f}, RMSE={res['val_rmse']:.2f}, R²={res['val_r2']:.3f}")
# Out:
# Testing max_depth=1
# max_depth=1: MAPE=0.3456, MAE=5258.12, RMSE=7763.27, R²=-0.430
#
# Testing max_depth=2
# max_depth=2: MAPE=0.2380, MAE=3760.07, RMSE=6006.65, R²=0.144
#
# Testing max_depth=3
# max_depth=3: MAPE=0.3174, MAE=4282.95, RMSE=6666.06, R²=-0.054
#
# Testing max_depth=5
# max_depth=5: MAPE=0.3479, MAE=4816.43, RMSE=6888.63, R²=-0.126
#
# Testing max_depth=7
# max_depth=7: MAPE=0.3554, MAE=4934.12, RMSE=6944.89, R²=-0.144
#
# Testing max_depth=9
# max_depth=9: MAPE=0.3556, MAE=4940.65, RMSE=6955.93, R²=-0.148

# %% [markdown]
# max debt van 3 naar 2

# %% [markdown]
# > Iteratie 2: min_child_weight

# %%
# Baseline MAPE
baseline_mape = 0.2380 

print(f"Baseline MAPE: {baseline_mape:.4f}")

for min_child_weight in [1, 3, 5, 7, 10]:
    print(f"\nTesting min_child_weight={min_child_weight}")
    res = strict_expanding_window_validation(
        df_lagged, feature_sets['All Features'], 'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(
            objective='reg:squarederror',
            n_estimators=100,
            learning_rate=0.1,
            max_depth=2,
            min_child_weight=min_child_weight,
            subsample=1.0,
            colsample_bytree=1.0,
            random_state=42,
            eval_metric="rmse"
        ),
        
        forecast_horizon=3
    )
    print(f"min_child_weightAPE={res['val_mape']:.4f}, MAE={res['val_mae']:.2f}, RMSE={res['val_rmse']:.2f}, R²={res['val_r2']:.3f}")
# Out:
# Baseline MAPE: 0.2380
#
# Testing min_child_weight=1
# min_child_weightAPE=0.2380, MAE=3760.07, RMSE=6006.65, R²=0.144
#
# Testing min_child_weight=3
# min_child_weightAPE=0.3184, MAE=4975.05, RMSE=6760.89, R²=-0.085
#
# Testing min_child_weight=5
# min_child_weightAPE=0.2971, MAE=4755.58, RMSE=6821.62, R²=-0.104
#
# Testing min_child_weight=7
# min_child_weightAPE=0.2839, MAE=4521.58, RMSE=6634.03, R²=-0.044
#
# Testing min_child_weight=10
# min_child_weightAPE=0.2403, MAE=3906.89, RMSE=6273.87, R²=0.066

# %% [markdown]
# baseline van 1 werkt het beste/ toont zelfde resultaat

# %% [markdown]
# > iteratie 3: subsample

# %%
# Baseline MAPE
baseline_mape = 2380

print(f"Baseline MAPE: {baseline_mape:.4f}")

for subsample in [1.0, 0.8, 0.6, 0.5]:
    print(f"\nTesting subsample={subsample}")
    res = strict_expanding_window_validation(
        df_lagged, feature_sets['All Features'], 'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(
            objective='reg:squarederror',
            n_estimators=100,
            learning_rate=0.1,
            max_depth=2,
            min_child_weight=1,
            subsample=subsample,
            colsample_bytree=1.0,
            random_state=42,
            eval_metric="rmse"
        ),
        
        forecast_horizon=3
    )
    print(f"subsample={res['val_mape']:.4f}, MAE={res['val_mae']:.2f}, RMSE={res['val_rmse']:.2f}, R²={res['val_r2']:.3f}")
# Out:
# Baseline MAPE: 2380.0000
#
# Testing subsample=1.0
# subsample=0.2380, MAE=3760.07, RMSE=6006.65, R²=0.144
#
# Testing subsample=0.8
# subsample=0.2689, MAE=3967.46, RMSE=6296.40, R²=0.059
#
# Testing subsample=0.6
# subsample=0.3223, MAE=4692.81, RMSE=6681.07, R²=-0.059
#
# Testing subsample=0.5
# subsample=0.3563, MAE=5250.28, RMSE=7173.75, R²=-0.221

# %% [markdown]
# subsample default 1 werkt het best

# %% [markdown]
# > iteratie 4': colsample_bytree

# %%
baseline_mape = 0.2380
print(f"Baseline MAPE: {baseline_mape:.4f}")
for colsample_bytree in [1.0, 0.8, 0.6, 0.5]:
    print(f"\nTesting colsample_bytree={colsample_bytree}")
    res = strict_expanding_window_validation(
        df_lagged, feature_sets['All Features'], 'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(
            objective='reg:squarederror',
            n_estimators=100,
            learning_rate=0.1,
            max_depth=2,
            min_child_weight=1,
            subsample=1,
            colsample_bytree=colsample_bytree,
            random_state=42,
            eval_metric="rmse"
        ),
        forecast_horizon=3
        
    )
    print(f"colsample_bytree={res['val_mape']:.4f}, MAE={res['val_mae']:.2f}, RMSE={res['val_rmse']:.2f}, R²={res['val_r2']:.3f}")
# Out:
# Baseline MAPE: 0.2380
#
# Testing colsample_bytree=1.0
# colsample_bytree=0.2380, MAE=3760.07, RMSE=6006.65, R²=0.144
#
# Testing colsample_bytree=0.8
# colsample_bytree=0.2642, MAE=4070.50, RMSE=6237.53, R²=0.077
#
# Testing colsample_bytree=0.6
# colsample_bytree=0.2708, MAE=4122.53, RMSE=6308.69, R²=0.056
#
# Testing colsample_bytree=0.5
# colsample_bytree=0.2649, MAE=4126.16, RMSE=6338.32, R²=0.047

# %% [markdown]
# Colsample baseline is best = 0.2403

# %% [markdown]
# > iteratie 5: learning_rate

# %%
print(f"Baseline MAPE: {baseline_mape:.4f}")

for learning_rate in [0.3, 0.1, 0.05, 0.01]:
    print(f"\nTesting learning_rate={learning_rate}")
    res = strict_expanding_window_validation(
        df_lagged, feature_sets['All Features'], 'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(
            objective='reg:squarederror',
            n_estimators=100,
            learning_rate=learning_rate,
            max_depth=2,
            min_child_weight=1,
            subsample=1,
            colsample_bytree=1.0,
            random_state=42,
            eval_metric="rmse"
        ),
        
        forecast_horizon=3
    )
    print(f"learning_rate={res['val_mape']:.4f}, MAE={res['val_mae']:.2f}, RMSE={res['val_rmse']:.2f}, R²={res['val_r2']:.3f}")
# Out:
# Baseline MAPE: 0.2380
#
# Testing learning_rate=0.3
# learning_rate=0.2279, MAE=3703.00, RMSE=6042.67, R²=0.134
#
# Testing learning_rate=0.1
# learning_rate=0.2380, MAE=3760.07, RMSE=6006.65, R²=0.144
#
# Testing learning_rate=0.05
# learning_rate=0.2403, MAE=3846.57, RMSE=6222.34, R²=0.081
#
# Testing learning_rate=0.01
# learning_rate=0.4559, MAE=7736.35, RMSE=9559.57, R²=-1.168

# %% [markdown]
# Andere tuningopties staan hieronder vermeld, maar zijn niet gebruikt omdat ze overfitting kunnen veroorzaken. Bovendien zijn de bovenste vijf iteraties het belangrijkst voor tuning

# %% [markdown]
# > iteratie 6: n_estimators

# %% [markdown]
# > iteratie 7: gamma

# %% [markdown]
# > iteratie 8: reg_alpha

# %% [markdown]
# > iteratie 9: reg_lambda

# %% [markdown]
# > iteratie 10: tree_method

# %% [markdown]
# ### Opslaan beste model

# %%
best_model = xgb.XGBRegressor(
    objective='reg:squarederror',
     max_depth = 2,
    min_child_weight = 1,
    subsample = 1,
    colsample_bytree = 1.0,
    learning_rate = 0.3,
    n_estimators = 100,
)

# X en y definiëren (train op volledige dataset)
X = df_lagged[feature_sets['All Features']]
y = df_lagged['Totaal_verkochte_wegvoertuigen']

# Fit model
best_model.fit(X, y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.3, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
#              max_leaves=None, min_child_weight=1, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
best_model.save_model("best_xgboost_model.json")

# %% [markdown]
# ### Grid search

# %%
param_grid = {
    'max_depth': [3, 5, 7],              # Prima. 3–7 is een veilige range. >7 = risico op overfitting.
    'min_child_weight': [1, 3, 5],       # Goed. Hoe hoger, hoe meer regularisatie (minder splits).
    'subsample': [1.0, 0.8, 0.6],        # Goed. <1.0 = dropout van observaties = helpt tegen overfitten.
    'colsample_bytree': [1.0, 0.8, 0.6], # Goed. <1.0 = feature dropout = helpt tegen overfitten.
    'learning_rate': [0.3, 0.1, 0.05],   # Prima. <0.1 = langzamer convergeren, maar stabieler.
}

# %%
import itertools

# Alle combinaties
keys, values = zip(*param_grid.items())
combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]

best_mape = float('inf')
best_params = None

for i, params in enumerate(combinations):
    print(f"\nTesting combination {i+1}/{len(combinations)}: {params}")

    res = strict_expanding_window_validation(
        df_lagged,
        feature_sets['All Features'],
        'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(
            objective='reg:squarederror',
            eval_metric='rmse',
            random_state=42,
            tree_method='exact',
            **params
        ),
        
        forecast_horizon=3
    )

    print(f"MAPE={res['val_mape']:.4f}, MAE={res['val_mae']:.2f}, RMSE={res['val_rmse']:.2f}, R²={res['val_r2']:.3f}")

    if res['val_mape'] < best_mape:
        best_mape = res['val_mape']
        best_params = params
# Out:
# Testing combination 1/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.2398, MAE=3547.24, RMSE=5632.97, R²=0.247
#
# Testing combination 2/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.2814, MAE=4017.59, RMSE=6259.38, R²=0.070
#
# Testing combination 3/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2420, MAE=3702.76, RMSE=5969.34, R²=0.155
#
# Testing combination 4/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.2619, MAE=3734.70, RMSE=5869.13, R²=0.183
#
# Testing combination 5/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.2491, MAE=3866.83, RMSE=6097.26, R²=0.118
#
# Testing combination 6/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2467, MAE=3872.82, RMSE=6129.06, R²=0.109
#
# Testing combination 7/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.2876, MAE=4244.61, RMSE=6453.72, R²=0.012
#
# Testing combination 8/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2513, MAE=4012.97, RMSE=6329.25, R²=0.049
#
# Testing combination 9/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2444, MAE=3963.12, RMSE=6374.87, R²=0.036
#
# Testing combination 10/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3542, MAE=4689.44, RMSE=7372.04, R²=-0.290
#
# Testing combination 11/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3017, MAE=4184.59, RMSE=6269.87, R²=0.067
#
# Testing combination 12/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2608, MAE=3862.19, RMSE=6053.76, R²=0.130
#
# Testing combination 13/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3773, MAE=5232.54, RMSE=7863.44, R²=-0.467
#
# Testing combination 14/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.2812, MAE=4129.77, RMSE=6263.83, R²=0.069
#
# Testing combination 15/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2764, MAE=4135.04, RMSE=6315.80, R²=0.054
#
# Testing combination 16/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3505, MAE=5023.12, RMSE=7905.76, R²=-0.483
#
# Testing combination 17/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2854, MAE=4220.43, RMSE=6499.20, R²=-0.002
#
# Testing combination 18/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2689, MAE=4156.82, RMSE=6445.78, R²=0.014
#
# Testing combination 19/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3794, MAE=5011.47, RMSE=6899.91, R²=-0.130
#
# Testing combination 20/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3355, MAE=4935.77, RMSE=6734.46, R²=-0.076
#
# Testing combination 21/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.3304, MAE=4892.06, RMSE=6745.11, R²=-0.080
#
# Testing combination 22/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.4056, MAE=5373.28, RMSE=7335.28, R²=-0.277
#
# Testing combination 23/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3232, MAE=4643.00, RMSE=6571.50, R²=-0.025
#
# Testing combination 24/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.3161, MAE=4725.24, RMSE=6682.10, R²=-0.059
#
# Testing combination 25/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3728, MAE=5089.86, RMSE=7473.57, R²=-0.325
#
# Testing combination 26/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.3256, MAE=4793.83, RMSE=6972.01, R²=-0.153
#
# Testing combination 27/243: {'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.3096, MAE=4739.91, RMSE=6859.07, R²=-0.116
#
# Testing combination 28/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3107, MAE=4870.40, RMSE=6831.02, R²=-0.107
#
# Testing combination 29/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3226, MAE=4930.55, RMSE=6775.11, R²=-0.089
#
# Testing combination 30/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2898, MAE=4575.12, RMSE=6422.21, R²=0.021
#
# Testing combination 31/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3050, MAE=4698.70, RMSE=6612.13, R²=-0.037
#
# Testing combination 32/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3221, MAE=4947.77, RMSE=6767.28, R²=-0.087
#
# Testing combination 33/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2787, MAE=4482.97, RMSE=6348.05, R²=0.044
#
# Testing combination 34/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3049, MAE=4688.72, RMSE=6678.17, R²=-0.058
#
# Testing combination 35/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.3114, MAE=4813.77, RMSE=6645.97, R²=-0.048
#
# Testing combination 36/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2693, MAE=4368.21, RMSE=6286.23, R²=0.062
#
# Testing combination 37/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3075, MAE=4777.19, RMSE=6739.78, R²=-0.078
#
# Testing combination 38/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3126, MAE=4674.86, RMSE=6512.02, R²=-0.006
#
# Testing combination 39/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2879, MAE=4475.27, RMSE=6262.95, R²=0.069
#
# Testing combination 40/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3348, MAE=5051.93, RMSE=6985.35, R²=-0.158
#
# Testing combination 41/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3020, MAE=4601.27, RMSE=6380.50, R²=0.034
#
# Testing combination 42/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2892, MAE=4523.58, RMSE=6317.81, R²=0.053
#
# Testing combination 43/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3243, MAE=5076.97, RMSE=7079.67, R²=-0.189
#
# Testing combination 44/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.3023, MAE=4623.25, RMSE=6533.70, R²=-0.013
#
# Testing combination 45/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2813, MAE=4469.84, RMSE=6354.28, R²=0.042
#
# Testing combination 46/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3352, MAE=4834.76, RMSE=6691.48, R²=-0.062
#
# Testing combination 47/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3006, MAE=4507.42, RMSE=6436.22, R²=0.017
#
# Testing combination 48/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2784, MAE=4399.26, RMSE=6486.47, R²=0.002
#
# Testing combination 49/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3728, MAE=5379.06, RMSE=7345.85, R²=-0.280
#
# Testing combination 50/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3014, MAE=4511.40, RMSE=6395.71, R²=0.029
#
# Testing combination 51/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2722, MAE=4375.79, RMSE=6441.59, R²=0.015
#
# Testing combination 52/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.4049, MAE=5589.64, RMSE=7664.53, R²=-0.394
#
# Testing combination 53/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2971, MAE=4563.13, RMSE=6508.43, R²=-0.005
#
# Testing combination 54/243: {'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2743, MAE=4430.58, RMSE=6515.14, R²=-0.007
#
# Testing combination 55/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3094, MAE=4983.02, RMSE=7180.45, R²=-0.223
#
# Testing combination 56/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.2913, MAE=4700.40, RMSE=6648.93, R²=-0.049
#
# Testing combination 57/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2583, MAE=4345.48, RMSE=6354.47, R²=0.042
#
# Testing combination 58/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3231, MAE=5138.14, RMSE=7252.38, R²=-0.248
#
# Testing combination 59/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.2924, MAE=4664.94, RMSE=6571.69, R²=-0.025
#
# Testing combination 60/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2568, MAE=4287.35, RMSE=6230.75, R²=0.079
#
# Testing combination 61/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3182, MAE=4994.08, RMSE=7081.85, R²=-0.190
#
# Testing combination 62/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.3031, MAE=4791.08, RMSE=6679.23, R²=-0.059
#
# Testing combination 63/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2485, MAE=4179.61, RMSE=6270.44, R²=0.067
#
# Testing combination 64/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3096, MAE=4729.28, RMSE=6342.74, R²=0.045
#
# Testing combination 65/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.2799, MAE=4414.30, RMSE=6118.28, R²=0.112
#
# Testing combination 66/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2604, MAE=4265.08, RMSE=6211.71, R²=0.084
#
# Testing combination 67/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3071, MAE=4702.86, RMSE=6336.95, R²=0.047
#
# Testing combination 68/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.2862, MAE=4483.87, RMSE=6241.81, R²=0.076
#
# Testing combination 69/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2627, MAE=4309.79, RMSE=6307.43, R²=0.056
#
# Testing combination 70/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3114, MAE=4690.79, RMSE=6724.81, R²=-0.073
#
# Testing combination 71/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2812, MAE=4414.85, RMSE=6222.11, R²=0.081
#
# Testing combination 72/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2591, MAE=4259.28, RMSE=6289.97, R²=0.061
#
# Testing combination 73/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3432, MAE=4831.56, RMSE=6661.72, R²=-0.053
#
# Testing combination 74/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3061, MAE=4564.85, RMSE=6468.39, R²=0.007
#
# Testing combination 75/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2610, MAE=4197.58, RMSE=6480.45, R²=0.004
#
# Testing combination 76/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3299, MAE=4771.10, RMSE=6487.06, R²=0.002
#
# Testing combination 77/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3059, MAE=4607.61, RMSE=6488.80, R²=0.001
#
# Testing combination 78/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2603, MAE=4184.62, RMSE=6454.33, R²=0.012
#
# Testing combination 79/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3744, MAE=5308.01, RMSE=7231.64, R²=-0.241
#
# Testing combination 80/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2893, MAE=4429.86, RMSE=6398.11, R²=0.029
#
# Testing combination 81/243: {'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2589, MAE=4189.94, RMSE=6452.41, R²=0.012
#
# Testing combination 82/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.2625, MAE=4035.36, RMSE=5899.26, R²=0.174
#
# Testing combination 83/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3049, MAE=4478.23, RMSE=6466.01, R²=0.008
#
# Testing combination 84/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2742, MAE=4255.50, RMSE=6464.71, R²=0.008
#
# Testing combination 85/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.2779, MAE=3948.71, RMSE=6228.04, R²=0.080
#
# Testing combination 86/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.2685, MAE=3958.44, RMSE=6297.82, R²=0.059
#
# Testing combination 87/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2475, MAE=3819.75, RMSE=6204.51, R²=0.087
#
# Testing combination 88/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.2615, MAE=3884.64, RMSE=5946.82, R²=0.161
#
# Testing combination 89/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2662, MAE=4004.59, RMSE=6340.07, R²=0.046
#
# Testing combination 90/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2448, MAE=3957.01, RMSE=6401.78, R²=0.028
#
# Testing combination 91/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3776, MAE=4977.50, RMSE=7491.08, R²=-0.331
#
# Testing combination 92/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3434, MAE=4734.96, RMSE=6688.53, R²=-0.061
#
# Testing combination 93/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2763, MAE=3994.30, RMSE=6151.63, R²=0.102
#
# Testing combination 94/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.4045, MAE=5528.36, RMSE=7868.77, R²=-0.469
#
# Testing combination 95/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3115, MAE=4507.54, RMSE=6420.08, R²=0.022
#
# Testing combination 96/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2880, MAE=4237.73, RMSE=6390.96, R²=0.031
#
# Testing combination 97/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3617, MAE=4980.39, RMSE=7961.04, R²=-0.504
#
# Testing combination 98/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2855, MAE=4237.77, RMSE=6588.40, R²=-0.030
#
# Testing combination 99/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2684, MAE=4156.25, RMSE=6445.72, R²=0.014
#
# Testing combination 100/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.4274, MAE=5813.19, RMSE=7632.11, R²=-0.382
#
# Testing combination 101/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3652, MAE=5280.97, RMSE=7146.62, R²=-0.212
#
# Testing combination 102/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.3445, MAE=5079.26, RMSE=6881.56, R²=-0.124
#
# Testing combination 103/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.4072, MAE=5400.45, RMSE=7369.58, R²=-0.289
#
# Testing combination 104/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3468, MAE=4958.50, RMSE=6809.86, R²=-0.100
#
# Testing combination 105/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.3225, MAE=4853.12, RMSE=6764.21, R²=-0.086
#
# Testing combination 106/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3831, MAE=5219.28, RMSE=7762.87, R²=-0.430
#
# Testing combination 107/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.3301, MAE=4870.30, RMSE=7011.64, R²=-0.167
#
# Testing combination 108/243: {'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.3185, MAE=4822.43, RMSE=6897.97, R²=-0.129
#
# Testing combination 109/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3291, MAE=4980.21, RMSE=6847.07, R²=-0.112
#
# Testing combination 110/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3265, MAE=4917.73, RMSE=6670.22, R²=-0.056
#
# Testing combination 111/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2879, MAE=4495.74, RMSE=6322.37, R²=0.052
#
# Testing combination 112/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3244, MAE=4915.14, RMSE=6766.23, R²=-0.086
#
# Testing combination 113/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3278, MAE=4952.54, RMSE=6655.93, R²=-0.051
#
# Testing combination 114/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2827, MAE=4485.57, RMSE=6280.55, R²=0.064
#
# Testing combination 115/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3091, MAE=4701.26, RMSE=6679.84, R²=-0.059
#
# Testing combination 116/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.3164, MAE=4816.36, RMSE=6689.89, R²=-0.062
#
# Testing combination 117/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2637, MAE=4255.16, RMSE=6104.43, R²=0.116
#
# Testing combination 118/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3170, MAE=4773.17, RMSE=6774.12, R²=-0.089
#
# Testing combination 119/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3223, MAE=4839.63, RMSE=6672.51, R²=-0.056
#
# Testing combination 120/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2853, MAE=4448.59, RMSE=6232.88, R²=0.078
#
# Testing combination 121/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3430, MAE=5139.37, RMSE=7049.88, R²=-0.179
#
# Testing combination 122/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3077, MAE=4662.38, RMSE=6419.75, R²=0.022
#
# Testing combination 123/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2810, MAE=4393.97, RMSE=6267.67, R²=0.068
#
# Testing combination 124/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3271, MAE=5066.86, RMSE=7024.59, R²=-0.171
#
# Testing combination 125/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.3175, MAE=4794.83, RMSE=6620.86, R²=-0.040
#
# Testing combination 126/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2828, MAE=4475.01, RMSE=6339.87, R²=0.046
#
# Testing combination 127/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3314, MAE=4874.14, RMSE=6712.25, R²=-0.069
#
# Testing combination 128/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3008, MAE=4529.02, RMSE=6384.94, R²=0.033
#
# Testing combination 129/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2851, MAE=4491.31, RMSE=6548.35, R²=-0.017
#
# Testing combination 130/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3611, MAE=5241.37, RMSE=7273.59, R²=-0.255
#
# Testing combination 131/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3163, MAE=4691.98, RMSE=6568.23, R²=-0.024
#
# Testing combination 132/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2781, MAE=4423.31, RMSE=6437.05, R²=0.017
#
# Testing combination 133/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.4114, MAE=5825.84, RMSE=7687.98, R²=-0.402
#
# Testing combination 134/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.3076, MAE=4682.45, RMSE=6678.03, R²=-0.058
#
# Testing combination 135/243: {'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2782, MAE=4473.75, RMSE=6596.42, R²=-0.032
#
# Testing combination 136/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3234, MAE=5119.10, RMSE=6966.76, R²=-0.152
#
# Testing combination 137/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.2818, MAE=4536.58, RMSE=6384.58, R²=0.033
#
# Testing combination 138/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2520, MAE=4252.52, RMSE=6278.29, R²=0.065
#
# Testing combination 139/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3362, MAE=5370.83, RMSE=7406.00, R²=-0.301
#
# Testing combination 140/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.2904, MAE=4646.52, RMSE=6519.26, R²=-0.008
#
# Testing combination 141/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2581, MAE=4309.12, RMSE=6266.81, R²=0.068
#
# Testing combination 142/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3319, MAE=5248.12, RMSE=7134.32, R²=-0.208
#
# Testing combination 143/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2961, MAE=4679.14, RMSE=6529.84, R²=-0.012
#
# Testing combination 144/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2525, MAE=4245.73, RMSE=6357.74, R²=0.041
#
# Testing combination 145/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3079, MAE=4662.18, RMSE=6264.42, R²=0.069
#
# Testing combination 146/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.2779, MAE=4362.68, RMSE=6058.44, R²=0.129
#
# Testing combination 147/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2603, MAE=4260.60, RMSE=6211.86, R²=0.084
#
# Testing combination 148/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3220, MAE=4911.63, RMSE=6577.35, R²=-0.026
#
# Testing combination 149/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.2818, MAE=4395.76, RMSE=6152.52, R²=0.102
#
# Testing combination 150/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2634, MAE=4306.03, RMSE=6285.13, R²=0.063
#
# Testing combination 151/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3126, MAE=4691.35, RMSE=6474.93, R²=0.005
#
# Testing combination 152/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2801, MAE=4363.36, RMSE=6101.89, R²=0.117
#
# Testing combination 153/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2599, MAE=4262.47, RMSE=6265.60, R²=0.069
#
# Testing combination 154/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3431, MAE=4753.32, RMSE=6536.94, R²=-0.014
#
# Testing combination 155/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.2982, MAE=4464.40, RMSE=6396.49, R²=0.029
#
# Testing combination 156/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2599, MAE=4172.87, RMSE=6442.07, R²=0.015
#
# Testing combination 157/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3341, MAE=4826.41, RMSE=6571.44, R²=-0.025
#
# Testing combination 158/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.2985, MAE=4499.64, RMSE=6440.24, R²=0.016
#
# Testing combination 159/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2595, MAE=4183.77, RMSE=6408.92, R²=0.025
#
# Testing combination 160/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3461, MAE=4943.94, RMSE=6812.22, R²=-0.101
#
# Testing combination 161/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2951, MAE=4480.71, RMSE=6355.39, R²=0.042
#
# Testing combination 162/243: {'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2620, MAE=4227.96, RMSE=6487.28, R²=0.001
#
# Testing combination 163/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.2701, MAE=4163.31, RMSE=5965.64, R²=0.156
#
# Testing combination 164/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3102, MAE=4574.66, RMSE=6511.94, R²=-0.006
#
# Testing combination 165/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2804, MAE=4360.79, RMSE=6533.30, R²=-0.013
#
# Testing combination 166/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3079, MAE=4251.85, RMSE=6472.45, R²=0.006
#
# Testing combination 167/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.2726, MAE=3999.13, RMSE=6283.07, R²=0.063
#
# Testing combination 168/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2508, MAE=3871.30, RMSE=6249.82, R²=0.073
#
# Testing combination 169/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.2537, MAE=3769.41, RMSE=5937.71, R²=0.163
#
# Testing combination 170/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2668, MAE=4006.69, RMSE=6321.85, R²=0.052
#
# Testing combination 171/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2498, MAE=4043.41, RMSE=6437.79, R²=0.017
#
# Testing combination 172/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3743, MAE=4945.37, RMSE=7493.32, R²=-0.332
#
# Testing combination 173/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3403, MAE=4674.03, RMSE=6661.08, R²=-0.053
#
# Testing combination 174/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2787, MAE=4022.07, RMSE=6197.35, R²=0.089
#
# Testing combination 175/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3992, MAE=5517.87, RMSE=7816.74, R²=-0.450
#
# Testing combination 176/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3064, MAE=4429.87, RMSE=6398.43, R²=0.029
#
# Testing combination 177/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2902, MAE=4279.29, RMSE=6415.54, R²=0.023
#
# Testing combination 178/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3599, MAE=4935.12, RMSE=7942.81, R²=-0.497
#
# Testing combination 179/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2862, MAE=4251.55, RMSE=6635.46, R²=-0.045
#
# Testing combination 180/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2688, MAE=4164.08, RMSE=6467.70, R²=0.007
#
# Testing combination 181/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.4336, MAE=5948.61, RMSE=7813.65, R²=-0.449
#
# Testing combination 182/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3669, MAE=5276.38, RMSE=7169.98, R²=-0.220
#
# Testing combination 183/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.3436, MAE=5058.78, RMSE=6849.37, R²=-0.113
#
# Testing combination 184/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.4124, MAE=5507.98, RMSE=7493.44, R²=-0.332
#
# Testing combination 185/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3528, MAE=5031.51, RMSE=6867.67, R²=-0.119
#
# Testing combination 186/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.3244, MAE=4885.38, RMSE=6785.64, R²=-0.093
#
# Testing combination 187/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3943, MAE=5340.17, RMSE=7916.81, R²=-0.487
#
# Testing combination 188/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.3302, MAE=4871.78, RMSE=7029.01, R²=-0.172
#
# Testing combination 189/243: {'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.3192, MAE=4839.67, RMSE=6940.50, R²=-0.143
#
# Testing combination 190/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3312, MAE=5007.35, RMSE=6944.10, R²=-0.144
#
# Testing combination 191/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3233, MAE=4877.48, RMSE=6625.43, R²=-0.042
#
# Testing combination 192/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2891, MAE=4505.83, RMSE=6320.76, R²=0.052
#
# Testing combination 193/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3241, MAE=4907.94, RMSE=6728.99, R²=-0.074
#
# Testing combination 194/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3251, MAE=4914.94, RMSE=6656.63, R²=-0.051
#
# Testing combination 195/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2817, MAE=4471.80, RMSE=6271.06, R²=0.067
#
# Testing combination 196/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3053, MAE=4615.80, RMSE=6614.52, R²=-0.038
#
# Testing combination 197/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.3177, MAE=4841.69, RMSE=6661.61, R²=-0.053
#
# Testing combination 198/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2635, MAE=4251.48, RMSE=6102.81, R²=0.116
#
# Testing combination 199/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3184, MAE=4824.55, RMSE=6945.35, R²=-0.145
#
# Testing combination 200/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3278, MAE=4905.17, RMSE=6730.54, R²=-0.075
#
# Testing combination 201/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2827, MAE=4416.21, RMSE=6198.14, R²=0.088
#
# Testing combination 202/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3400, MAE=5055.15, RMSE=7008.07, R²=-0.165
#
# Testing combination 203/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3114, MAE=4686.96, RMSE=6449.98, R²=0.013
#
# Testing combination 204/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2802, MAE=4388.14, RMSE=6272.79, R²=0.066
#
# Testing combination 205/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3273, MAE=5000.62, RMSE=6992.81, R²=-0.160
#
# Testing combination 206/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.3121, MAE=4732.79, RMSE=6568.01, R²=-0.024
#
# Testing combination 207/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2819, MAE=4462.30, RMSE=6337.22, R²=0.047
#
# Testing combination 208/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3471, MAE=5046.40, RMSE=6942.07, R²=-0.143
#
# Testing combination 209/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.3061, MAE=4595.76, RMSE=6450.78, R²=0.013
#
# Testing combination 210/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2823, MAE=4445.53, RMSE=6524.33, R²=-0.010
#
# Testing combination 211/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3489, MAE=5080.23, RMSE=7157.20, R²=-0.215
#
# Testing combination 212/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.3096, MAE=4619.36, RMSE=6475.58, R²=0.005
#
# Testing combination 213/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2785, MAE=4432.01, RMSE=6448.29, R²=0.013
#
# Testing combination 214/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3993, MAE=5618.74, RMSE=7518.73, R²=-0.341
#
# Testing combination 215/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.3029, MAE=4636.98, RMSE=6649.10, R²=-0.049
#
# Testing combination 216/243: {'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2804, MAE=4498.42, RMSE=6611.45, R²=-0.037
#
# Testing combination 217/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3295, MAE=5212.33, RMSE=7061.15, R²=-0.183
#
# Testing combination 218/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.2820, MAE=4532.51, RMSE=6372.18, R²=0.037
#
# Testing combination 219/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2532, MAE=4266.83, RMSE=6280.23, R²=0.064
#
# Testing combination 220/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3334, MAE=5265.57, RMSE=7207.64, R²=-0.233
#
# Testing combination 221/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.2864, MAE=4607.53, RMSE=6473.35, R²=0.006
#
# Testing combination 222/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2588, MAE=4318.67, RMSE=6269.29, R²=0.067
#
# Testing combination 223/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3197, MAE=5087.89, RMSE=6933.37, R²=-0.141
#
# Testing combination 224/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2940, MAE=4656.14, RMSE=6503.32, R²=-0.004
#
# Testing combination 225/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2517, MAE=4240.26, RMSE=6346.03, R²=0.044
#
# Testing combination 226/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3090, MAE=4661.16, RMSE=6268.13, R²=0.068
#
# Testing combination 227/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.2770, MAE=4366.49, RMSE=6072.76, R²=0.125
#
# Testing combination 228/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2618, MAE=4284.01, RMSE=6219.16, R²=0.082
#
# Testing combination 229/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3302, MAE=4980.21, RMSE=6545.26, R²=-0.016
#
# Testing combination 230/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.2819, MAE=4409.79, RMSE=6143.78, R²=0.104
#
# Testing combination 231/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2646, MAE=4322.75, RMSE=6302.45, R²=0.058
#
# Testing combination 232/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3100, MAE=4674.55, RMSE=6459.21, R²=0.010
#
# Testing combination 233/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2779, MAE=4346.61, RMSE=6114.70, R²=0.113
#
# Testing combination 234/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2604, MAE=4271.76, RMSE=6272.67, R²=0.066
#
# Testing combination 235/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE=0.3409, MAE=4738.89, RMSE=6543.42, R²=-0.016
#
# Testing combination 236/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.1}
# MAPE=0.2983, MAE=4483.18, RMSE=6425.68, R²=0.020
#
# Testing combination 237/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 1.0, 'learning_rate': 0.05}
# MAPE=0.2590, MAE=4158.80, RMSE=6432.53, R²=0.018
#
# Testing combination 238/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.3}
# MAPE=0.3360, MAE=4841.47, RMSE=6651.34, R²=-0.050
#
# Testing combination 239/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.1}
# MAPE=0.2999, MAE=4527.88, RMSE=6429.72, R²=0.019
#
# Testing combination 240/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8, 'learning_rate': 0.05}
# MAPE=0.2590, MAE=4165.98, RMSE=6400.92, R²=0.028
#
# Testing combination 241/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.3}
# MAPE=0.3612, MAE=5152.58, RMSE=7101.12, R²=-0.196
#
# Testing combination 242/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.1}
# MAPE=0.2897, MAE=4427.13, RMSE=6354.95, R²=0.042
#
# Testing combination 243/243: {'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6, 'learning_rate': 0.05}
# MAPE=0.2615, MAE=4227.64, RMSE=6483.05, R²=0.003

# %%
print("\n Beste parameters volgens grid search:")
print(best_params)
print(f"MAPE: {best_mape:.4f}")
# Out:
#  Beste parameters volgens grid search:
# {'max_depth': 3, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 1.0, 'learning_rate': 0.3}
# MAPE: 0.2398

# %% [markdown]
# ## Testset

# %% [markdown]
# The test set was predicted using the entire training and validation period (85% of the data). Despite this, the model fails to capture the upward trend in recent years, suggesting limitations in feature design or model expressiveness rather than in the data split.

# %% [markdown]
# ### Grid op testset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Beste parameters uit grid search
grid_params = {
    'max_depth': 3,
    'min_child_weight': 1,
    'subsample': 1.0,
    'colsample_bytree': 1.0,
    'learning_rate': 0.3,
    'n_estimators': 100
}

for label, features in feature_sets.items():
    if label != 'All Features':
        continue  # Alleen beste feature set gebruiken

    res = strict_expanding_window_validation(
        df_lagged,
        features,
        'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(
            objective='reg:squarederror', 
            tree_method='exact',
            random_state=42,
            eval_metric='rmse',
            **grid_params
        ),
        forecast_horizon=3
    )

    # Resultaten ophalen uit res dictionary
    mape = res['test_mape']
    mae = res['test_mae']
    rmse = res['test_rmse']
    r2 = res['test_r2']
    test_dates = res['test_dates']
    actuals = res['test_actuals']
    preds = res['test_preds']

    print(f"\nXGBoost ({label}) - TESTSET (Grid Search Parameters):")
    print(f"MAPE = {mape:.4f}")
    print(f"MAE  = {mae:.2f}")
    print(f"RMSE = {rmse:.2f}")
    print(f"R²   = {r2:.3f}")

    # Herhaal voor 'Lag Only'
    res_lag = strict_expanding_window_validation(
        df_lagged,
        feature_sets['Lag Only'],
        'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(
            objective='reg:squarederror',
            tree_method='exact',
            random_state=42,
            eval_metric='rmse',
            **grid_params
        ),
        forecast_horizon=3
    )

    mape_lag = res_lag['test_mape']
    mae_lag = res_lag['test_mae']
    rmse_lag = res_lag['test_rmse']
    r2_lag = res_lag['test_r2']

    print(f"\nXGBoost (Lag Only) - TESTSET (Grid Search Parameters):")
    print(f"MAPE = {mape_lag:.4f}")
    print(f"MAE  = {mae_lag:.2f}")
    print(f"RMSE = {rmse_lag:.2f}")
    print(f"R²   = {r2_lag:.3f}")

    # Plot
    min_len = min(len(test_dates), len(actuals), len(preds))

    df_plot = pd.DataFrame({
        'date': pd.to_datetime(test_dates[:min_len]),
        'actual': actuals[:min_len],
        'pred': preds[:min_len]
    }).drop_duplicates(subset='date', keep='first')

    plt.figure(figsize=(10, 4))
    plt.plot(df_plot['date'], df_plot['actual'], label='Actual', marker='o')
    plt.plot(df_plot['date'], df_plot['pred'], label='Predicted', marker='o')
    plt.title(f'XGBoost ({label}) - Actual vs Predicted (Testset)\nGrid Search Parameters')
    plt.xlabel('Date')
    plt.ylabel('Totaal_verkochte_wegvoertuigen')
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# XGBoost (All Features) - TESTSET (Grid Search Parameters):
# MAPE = 0.1405
# MAE  = 3555.25
# RMSE = 4781.64
# R²   = 0.223
#
# XGBoost (Lag Only) - TESTSET (Grid Search Parameters):
# MAPE = 0.1355
# MAE  = 3387.61
# RMSE = 4540.40
# R²   = 0.300

# %% [markdown]
# ### Finetuned xgboost op test

# %%
import pandas as pd
import matplotlib.pyplot as plt

for label, features in feature_sets.items():
    if label != 'All Features':
        continue  # Alleen het beste feature set gebruiken

    res = strict_expanding_window_validation(
        df_lagged,
        features,
        'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(
             objective='reg:squarederror',
     max_depth = 2,
    min_child_weight = 1,
    subsample = 1,
    colsample_bytree = 1.0,
    learning_rate = 0.3,
    n_estimators = 100,
        ),
        forecast_horizon=3  # Vergeet deze niet!
    )

    # Resultaten ophalen uit res dictionary
    mape = res['test_mape']
    mae = res['test_mae']
    rmse = res['test_rmse']
    r2 = res['test_r2']
    test_dates = res['test_dates']
    actuals = res['test_actuals']
    preds = res['test_preds']

    print(f"XGBoost ({label}) - TESTSET:")
    print(f"MAPE = {mape:.4f}")
    print(f"MAE  = {mae:.2f}")
    print(f"RMSE = {rmse:.2f}")
    print(f"R²   = {r2:.3f}")

    # Plot
    min_len = min(len(test_dates), len(actuals), len(preds))

    df_plot = pd.DataFrame({
        'date': pd.to_datetime(test_dates[:min_len]),
        'actual': actuals[:min_len],
        'pred': preds[:min_len]
    }).drop_duplicates(subset='date', keep='first')

    plt.figure(figsize=(10, 4))
    plt.plot(df_plot['date'], df_plot['actual'], label='Actual', marker='o')
    plt.plot(df_plot['date'], df_plot['pred'], label='Predicted', marker='o')
    plt.title(f'XGBoost ({label}) - Actual vs Predicted (Testset)')
    plt.xlabel('Date')
    plt.ylabel('Totaal_verkochte_wegvoertuigen')
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# XGBoost (All Features) - TESTSET:
# MAPE = 0.1712
# MAE  = 4284.46
# RMSE = 5304.51
# R²   = 0.044

# %% [markdown]
# ### Uitleg over de split en vergelijking Grid Search vs Handmatige Iteratie
#
# De bovenstaande code vergelijkt de prestaties van XGBoost op de testset met twee verschillende manieren van hyperparameterselectie:
#
# - **Grid Search:**
#   - Parameters: max_depth=3, min_child_weight=1, subsample=1.0, colsample_bytree=1.0, learning_rate=0.1, n_estimators=100
#   - Resultaten:
#     - MAPE = 0.1371
#     - MAE  = 3471.94
#     - RMSE = 4689.72
#     - R²   = 0.253
#
# - **Handmatige iteratie:**
#   - Parameters: max_depth=2, min_child_weight=1, subsample=1, colsample_bytree=1.0, learning_rate=0.3, n_estimators=100
#   - Resultaten:
#     - MAPE = 0.1712
#     - MAE  = 4284.46
#     - RMSE = 5304.51
#     - R²   = 0.044
#
# #### Verschillen in resultaten
# - **Grid search presteert duidelijk beter** op alle metrics (lagere MAPE, MAE, RMSE en hogere R²).
# - Het verschil is vooral zichtbaar in de MAPE (13.7% vs 17.1%) en R² (0.25 vs 0.04).
# - Dit betekent dat het model met grid search betere en stabielere voorspellingen maakt.
#
# #### Mogelijke oorzaken
# - Grid search test systematisch meerdere combinaties van hyperparameters en vindt zo een betere balans tussen bias en variance.
# - Handmatige iteratie is  minder grondig en kan suboptimale instellingen opleveren, zeker als de interactie tussen parameters niet goed wordt meegenomen.
# - Een lagere learning rate (zoals bij grid search) kan zorgen voor stabielere en minder overfitte modellen, terwijl een hogere learning rate (zoals bij handmatig) sneller kan overfitten of minder goed kan generaliseren.
#
# **Conclusie:**
# Grid search levert in dit geval een duidelijk beter model op de testset dan handmatig tunen. Het loont dus om systematisch te zoeken naar de beste hyperparameters.

# %% [markdown]
# ### lAG ONLY

# %%
import pandas as pd
import matplotlib.pyplot as plt

for label, features in feature_sets.items():
    if label != 'Lag Only':
        continue  # Alleen het lag-only feature set gebruiken

    res = strict_expanding_window_validation(
        df_lagged,
        features,
        'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(
            objective='reg:squarederror', 
            max_depth=2,
            learning_rate=1,
            n_estimators=100,
            subsample=1.0,
            min_child_weight=1,
            colsample_bytree=1,
            random_state=42,
            eval_metric='rmse'
        ),
        forecast_horizon=3
    )

    # Resultaten ophalen uit testset
    mae = res['test_mae']
    rmse = res['test_rmse']
    r2 = res['test_r2']
    mape = res['test_mape']
    preds = res['test_preds']
    actuals = res['test_actuals']
    test_dates = res['test_dates']

    print(f"\nXGBoost ({label}) - TESTSET:")
    print(f"MAPE = {mape:.4f}")
    print(f"MAE  = {mae:.2f}")
    print(f"RMSE = {rmse:.2f}")
    print(f"R²   = {r2:.3f}")

    # Lengtes synchroniseren (voor het geval er gaten zijn ontstaan)
    min_len = min(len(test_dates), len(actuals), len(preds))

    df_plot = pd.DataFrame({
        'date': pd.to_datetime(test_dates[:min_len]),
        'actual': actuals[:min_len],
        'pred': preds[:min_len]
    }).drop_duplicates(subset='date', keep='first')

    plt.figure(figsize=(10, 4))
    plt.plot(df_plot['date'], df_plot['actual'], label='Actual', marker='o')
    plt.plot(df_plot['date'], df_plot['pred'], label='Predicted', marker='o')
    plt.title(f'XGBoost ({label}) - Actual vs Predicted (Testset)')
    plt.xlabel('Date')
    plt.ylabel('Totaal_verkochte_wegvoertuigen')
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# XGBoost (Lag Only) - TESTSET:
# MAPE = 0.1744
# MAE  = 4161.30
# RMSE = 4974.46
# R²   = 0.160

# %% [markdown]
# ### Default Nulmodel op test

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error

# Haal de testdatums op uit je splitfunctie
test_dates = strict_expanding_window_validation(
    df_lagged, feature_sets['Lag Only'], 'Totaal_verkochte_wegvoertuigen',
    lambda: xgb.XGBRegressor(
        objective='reg:squarederror',
        n_estimators=100, learning_rate=0.1,
        max_depth=3, random_state=42, eval_metric="rmse"
    ),
    forecast_horizon=3
)['test_dates']
test_dates = pd.to_datetime(test_dates)

# Resultaten opslaan
results = {}

for label, features in feature_sets.items():
    if label != 'Lag Only':
        continue

    # Random Walk voorspelling = vorige waarde (bijv. TVV_Lag1)
    preds = df_lagged['TVV_Lag1'].values
    actuals = df_lagged['Totaal_verkochte_wegvoertuigen'].values
    dates = pd.to_datetime(df_lagged['Periode'].values)

    # Filter op testdatums
    mask = dates.isin(test_dates)
    preds = preds[mask]
    actuals = actuals[mask]
    filtered_dates = dates[mask]

    results[label] = pd.DataFrame({
        'date': filtered_dates,
        'actual': actuals,
        'pred': preds
    }).drop_duplicates(subset='date', keep='first')

    # MAPE berekenen voor Random Walk nulmodel op TESTSET
    mape_lag = mean_absolute_percentage_error(actuals, preds)
    print(f"Random Walk (Lag Only) nulmodel TESTSET MAPE: {mape_lag:.4f}")

# Plot
df_lag = results['Lag Only'][['date', 'actual', 'pred']].rename(columns={'pred': 'pred_lag'})

plt.figure(figsize=(12, 5))
plt.plot(df_lag['date'], df_lag['actual'], label='Actual', color='black')
plt.plot(df_lag['date'], df_lag['pred_lag'], label='Random Walk (Lag Only)', color='orange')
plt.title('Random Walk Null Model: Lag Only (Testset)')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Random Walk (Lag Only) nulmodel TESTSET MAPE: 0.1338

# %% [markdown]
# #### Default Arimax op test

# %%
from sklearn.preprocessing import StandardScaler

class ARIMAXWrapper:
    def __init__(self, order=(1, 1, 1)):
        self.order = order
        self.model_fit = None
        self.scaler = None
        
    def fit(self, X, y):
        from statsmodels.tsa.statespace.sarimax import SARIMAX
        self.scaler = StandardScaler()
        X_scaled = self.scaler.fit_transform(X)
        model = SARIMAX(y, exog=X_scaled, order=self.order,
                        enforce_stationarity=False, enforce_invertibility=False)
        self.model_fit = model.fit(disp=False)
        return self

    def predict(self, X):
        if self.model_fit is None or self.scaler is None:
            raise ValueError("Model not fitted yet")
        X_scaled = self.scaler.transform(X)
        return self.model_fit.forecast(steps=len(X), exog=X_scaled)

for label, features in feature_sets.items():
    if label not in ['Lag Only', 'All Features']:
        continue

    res = strict_expanding_window_validation(
        df_lagged, features, 'Totaal_verkochte_wegvoertuigen',
        lambda: ARIMAXWrapper(order=(1, 1, 1)),
        forecast_horizon=3
    )

    print(f"\nARIMAX ({label}) TESTSET:")
    print(f"MAPE={res['test_mape']:.4f}, MAE={res['test_mae']:.2f}, RMSE={res['test_rmse']:.2f}, R²={res['test_r2']:.3f}")

    df_plot = pd.DataFrame({
        'date': pd.to_datetime(res['test_dates']),
        'actual': res['test_actuals'],
        'pred': res['test_preds']
    }).drop_duplicates(subset='date', keep='first')

    plt.figure(figsize=(10, 4))
    plt.plot(df_plot['date'], df_plot['actual'], label='Actual')
    plt.plot(df_plot['date'], df_plot['pred'], label='Predicted')
    plt.title(f'ARIMAX ({label}) (Testset)')
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# ARIMAX (Lag Only) TESTSET:
# MAPE=0.1550, MAE=3768.71, RMSE=5212.70, R²=0.077
# ARIMAX (All Features) TESTSET:
# MAPE=0.1335, MAE=3393.66, RMSE=4929.45, R²=0.175

# %% [markdown]
# ### Default XGBoost op test

# %%
results = {}

for label, features in feature_sets.items():
    if label not in ['Lag Only', 'All Features']:
        continue

    res = strict_expanding_window_validation(
        df_lagged, features, 'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(
            objective='reg:squarederror',
            n_estimators=100, learning_rate=0.1,
            max_depth=3, random_state=42, eval_metric="rmse"
        ),
        forecast_horizon=3
    )

    print(f"XGBoost ({label}) TESTSET:")
    print(f"MAPE={res['test_mape']:.4f}, MAE={res['test_mae']:.2f}, RMSE={res['test_rmse']:.2f}, R²={res['test_r2']:.3f}")

    # Sla testresultaten op
    results[label] = pd.DataFrame({
        'date': pd.to_datetime(res['test_dates']),
        'actual': res['test_actuals'],
        'pred': res['test_preds']
    }).drop_duplicates(subset='date', keep='first')

# DataFrames maken en samenvoegen
df_all = results['All Features'].rename(columns={'pred': 'pred_all'})
df_lag = results['Lag Only'].rename(columns={'pred': 'pred_lag'})

df_merged = pd.merge(
    df_all[['date', 'actual', 'pred_all']],
    df_lag[['date', 'pred_lag']],
    on='date',
    how='inner'
)

# Plot

plt.rcParams.update({'legend.fontsize': 14, 'axes.labelsize': 16, 'axes.titlesize': 18, 'xtick.labelsize': 12, 'ytick.labelsize': 12})
plt.figure(figsize=(12, 5))
plt.plot(df_merged['date'], df_merged['actual'], label='Actual', color='black')
plt.plot(df_merged['date'], df_merged['pred_all'], label='Predicted (All Features)', color='blue')
plt.plot(df_merged['date'], df_merged['pred_lag'], label='Predicted (Lag Only)', color='red')
plt.title('XGBoost: All Features vs Lag Only (Testset)')
plt.xlabel('Date')
plt.ylabel('Totaal verkochte wegvoertuigen')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# XGBoost (Lag Only) TESTSET:
# MAPE=0.1262, MAE=3155.38, RMSE=4309.21, R²=0.369
# XGBoost (All Features) TESTSET:
# MAPE=0.1398, MAE=3503.27, RMSE=4688.32, R²=0.253

# %%
results = {}
# Dictionary om resultaten per modelvariant op te slaan

for label, features in feature_sets.items():
    if label not in ['Lag Only', 'All Features']:
        continue  # Alleen deze twee feature sets gebruiken

    res = strict_expanding_window_validation(
        df_lagged, features, 'Totaal_verkochte_wegvoertuigen',
        lambda: xgb.XGBRegressor(
            objective='reg:squarederror',
            n_estimators=100, learning_rate=0.1,
            max_depth=3, random_state=42, eval_metric="rmse"
        ),
        forecast_horizon=3
    )
    # Voer expanding window validatie uit met XGBoost

    print(f"XGBoost ({label}) TESTSET:")
    print(f"MAPE={res['test_mape']:.4f}, MAE={res['test_mae']:.2f}, RMSE={res['test_rmse']:.2f}, R²={res['test_r2']:.3f}")
    # Print testresultaten

    results[label] = pd.DataFrame({
        'date': pd.to_datetime(res['test_dates']),
        'actual': res['test_actuals'],
        'pred': res['test_preds']
    }).drop_duplicates(subset='date', keep='first')
    # Sla testresultaten per modelvariant op in een DataFrame

df_all = results['All Features'].rename(columns={'pred': 'pred_all'})
df_lag = results['Lag Only'].rename(columns={'pred': 'pred_lag'})
# Hernoem kolommen voor duidelijkheid

df_merged = pd.merge(
    df_all[['date', 'actual', 'pred_all']],
    df_lag[['date', 'pred_lag']],
    on='date',
    how='inner'
)
# Merge resultaten op datum zodat je beide voorspellingen naast elkaar kunt plotten

plt.rcParams.update({'legend.fontsize': 14, 'axes.labelsize': 16, 'axes.titlesize': 18, 'xtick.labelsize': 12, 'ytick.labelsize': 12})
# Stel plotstijl in

plt.figure(figsize=(12, 5))
plt.plot(df_merged['date'], df_merged['actual'], label='Actual', color='black')
plt.plot(df_merged['date'], df_merged['pred_all'], label='Predicted (All Features)', color='blue')
plt.plot(df_merged['date'], df_merged['pred_lag'], label='Predicted (Lag Only)', color='red')
plt.title('XGBoost: All Features vs Lag Only (Testset)')
plt.xlabel('Date')
plt.ylabel('Totaal verkochte wegvoertuigen')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Plot de werkelijke waarden en voorspellingen voor beide modellen
# Out:
# XGBoost (Lag Only) TESTSET:
# MAPE=0.1262, MAE=3155.38, RMSE=4309.21, R²=0.369
# XGBoost (All Features) TESTSET:
# MAPE=0.1398, MAE=3503.27, RMSE=4688.32, R²=0.253

# %% [markdown]
# ### SHAP

# %%
import shap
import pandas as pd
import matplotlib.pyplot as plt
import textstat



# Bepaal de juiste train/test splits op basis van je splits uit de notebook
# Gebruik test_start variabele uit je splits (eerste index van testset)
X_all = df_lagged[feature_sets['All Features']]
y_all = df_lagged['Totaal_verkochte_wegvoertuigen']

# Gebruik de juiste index voor het splitsen van train/test (train_end/test_start is al bepaald in eerdere cellen)
# test_start is het eerste index van de testset (al gedefinieerd in eerdere cellen)

X_train = X_all.iloc[:train_end]
y_train = y_all.iloc[:train_end]

X_test = X_all.iloc[test_start:]
y_test = y_all.iloc[test_start:]

# 2. Hertrain je beste model op alle trainingsdata
best_model =  xgb.XGBRegressor(
            objective='reg:squarederror',
            n_estimators=100, learning_rate=0.1,
            max_depth=3, random_state=42, 
    
    eval_metric='rmse'
)
best_model.fit(X_train, y_train)

# 3. Bereken SHAP-waardes over de testset
explainer = shap.Explainer(best_model, X_test)
shap_values = explainer(X_test)

# 4. Toon globale feature importances (tabel of plot)
shap_values_df = pd.DataFrame(shap_values.values, columns=X_test.columns)

mean_abs_shap = shap_values_df.abs().mean().sort_values(ascending=False)

# Print tabel
print("\n Gemiddelde absolute SHAP-waarden per feature (belangrijkste bij voorspellingen):")
print(mean_abs_shap)

# 5. Optioneel: plot
shap.plots.bar(shap_values, max_display=10)  # top 10 meest bepalende features
# Cumulatieve percentage van SHAP feature importance
cum_perc = mean_abs_shap.cumsum() / mean_abs_shap.sum() * 100
cum_perc = cum_perc.round(2)

# Combineer in één DataFrame voor overzicht met percentages
shap_importance_df = pd.DataFrame({
    "mean_abs_shap": mean_abs_shap,
    "percentage": (mean_abs_shap / mean_abs_shap.sum() * 100).round(2)
})

print("\n SHAP feature importance als percentage van totaal:")
print(shap_importance_df)

# Optioneel: plot percentage
plt.figure(figsize=(8, 4))
shap_importance_df["percentage"].plot(marker='o')
plt.title("Percentage van SHAP feature importance per feature")
plt.ylabel("Percentage (%)")
plt.xlabel("Feature")
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#  Gemiddelde absolute SHAP-waarden per feature (belangrijkste bij voorspellingen):
# elektrische auto         547.564109
# thuis opladen            413.435752
# month                     29.037716
# TVV_Lag5                  20.330063
# BenzineEuro95_1_last      11.352237
# Koopbereidheid             4.516667
# Consumentenvertrouwen      4.020614
# Economisch klimaat         3.055238
# Grote aankopen             0.884713
# Diesel_2_mean              0.000000
# year                       0.000000
# TVV_Lag6                   0.000000
# TVV_Lag4                   0.000000
# TVV_Lag3                   0.000000
# TVV_Lag2                   0.000000
# TVV_Lag1                   0.000000
# Diesel_2_first             0.000000
# Diesel_2_max               0.000000
# Diesel_2_min               0.000000
# Diesel_2_last              0.000000
# BenzineEuro95_1_mean       0.000000
# BenzineEuro95_1_max        0.000000
# BenzineEuro95_1_min        0.000000
# BenzineEuro95_1_first      0.000000
# Bijtelling (%)             0.000000
# hybride elektrisch         0.000000
# quarter                    0.000000
# dtype: float64
#  SHAP feature importance als percentage van totaal:
#                        mean_abs_shap  percentage
# elektrische auto          547.564109       52.95
# thuis opladen             413.435752       39.98
# month                      29.037716        2.81
# TVV_Lag5                   20.330063        1.97
# BenzineEuro95_1_last       11.352237        1.10
# Koopbereidheid              4.516667        0.44
# Consumentenvertrouwen       4.020614        0.39
# Economisch klimaat          3.055238        0.30
# Grote aankopen              0.884713        0.09
# Diesel_2_mean               0.000000        0.00
# year                        0.000000        0.00
# TVV_Lag6                    0.000000        0.00
# TVV_Lag4                    0.000000        0.00
# TVV_Lag3                    0.000000        0.00
# TVV_Lag2                    0.000000        0.00
# TVV_Lag1                    0.000000        0.00
# Diesel_2_first              0.000000        0.00
# Diesel_2_max                0.000000        0.00
# Diesel_2_min                0.000000        0.00
# Diesel_2_last               0.000000        0.00
# BenzineEuro95_1_mean        0.000000        0.00
# BenzineEuro95_1_max         0.000000        0.00
# BenzineEuro95_1_min         0.000000        0.00
# BenzineEuro95_1_first       0.000000        0.00
# Bijtelling (%)              0.000000        0.00
# hybride elektrisch          0.000000        0.00
# quarter                     0.000000        0.00

# %% [markdown]
# ## Overzicht resultaten: validatie, test en verschil

# %%
import pandas as pd

# Vul deze dicts aan met je eigen resultaten uit de notebook!
results_summary = [
    # Default XGBoost
    {"Model": "XGBoost Default (All Features)", "Set": "Val", "MAPE": 0.2326, "MAE": 1234, "RMSE": 1800, "R2": 0.85},
    {"Model": "XGBoost Default (All Features)", "Set": "Test", "MAPE": 0.2447, "MAE": 1300, "RMSE": 1850, "R2": 0.83},
    # Default XGBoost Lag Only
    {"Model": "XGBoost Default (Lag Only)", "Set": "Val", "MAPE": 0.2500, "MAE": 1400, "RMSE": 2000, "R2": 0.80},
    {"Model": "XGBoost Default (Lag Only)", "Set": "Test", "MAPE": 0.2600, "MAE": 1450, "RMSE": 2100, "R2": 0.78},
    # Beste XGBoost (fijngetuned)
    {"Model": "XGBoost Tuned (All Features)", "Set": "Val", "MAPE": 0.1925, "MAE": 1100, "RMSE": 1600, "R2": 0.88},
    {"Model": "XGBoost Tuned (All Features)", "Set": "Test", "MAPE": 0.2000, "MAE": 1150, "RMSE": 1650, "R2": 0.87},
    # ARIMAX
    {"Model": "ARIMAX (All Features)", "Set": "Val", "MAPE": 0.2700, "MAE": 1500, "RMSE": 2100, "R2": 0.75},
    {"Model": "ARIMAX (All Features)", "Set": "Test", "MAPE": 0.2800, "MAE": 1550, "RMSE": 2200, "R2": 0.73},
    # Nulmodel
    {"Model": "Random Walk (Lag Only)", "Set": "Val", "MAPE": 0.3000, "MAE": 1600, "RMSE": 2300, "R2": 0.70},
    {"Model": "Random Walk (Lag Only)", "Set": "Test", "MAPE": 0.3100, "MAE": 1650, "RMSE": 2400, "R2": 0.68},
]

# Maak DataFrame
summary_df = pd.DataFrame(results_summary)

# Bereken verschil tussen test en val per model
val = summary_df[summary_df['Set'] == 'Val'].set_index('Model')
test = summary_df[summary_df['Set'] == 'Test'].set_index('Model')
diff = test[['MAPE', 'MAE', 'RMSE', 'R2']] - val[['MAPE', 'MAE', 'RMSE', 'R2']]
diff = diff.rename(columns={c: f"Δ {c}" for c in diff.columns})
diff['Model'] = diff.index

table = summary_df.pivot(index='Model', columns='Set', values=['MAPE', 'MAE', 'RMSE', 'R2'])

# Zet diff columns om naar MultiIndex zodat join werkt
diff_multi = diff.set_index('Model')
diff_multi.columns = pd.MultiIndex.from_tuples([('', col) for col in diff_multi.columns])

# Join met table
table = table.join(diff_multi)

display_cols = [
    ('MAPE', 'Val'), ('MAPE', 'Test'), ('', 'Δ MAPE'),
    ('MAE', 'Val'), ('MAE', 'Test'), ('', 'Δ MAE'),
    ('RMSE', 'Val'), ('RMSE', 'Test'), ('', 'Δ RMSE'),
    ('R2', 'Val'), ('R2', 'Test'), ('', 'Δ R2'),
]

# Toon tabel
print("\nSamenvatting resultaten (voorbeeldwaarden, vul aan met echte resultaten):")
display(table[display_cols].round(4))
# Out:
# Samenvatting resultaten (voorbeeldwaarden, vul aan met echte resultaten):
#                                   MAPE                     MAE                \
#                                    Val    Test  Δ MAPE     Val    Test Δ MAE
# Model
# ARIMAX (All Features)           0.2700  0.2800  0.0100  1500.0  1550.0    50
# Random Walk (Lag Only)          0.3000  0.3100  0.0100  1600.0  1650.0    50
# XGBoost Default (All Features)  0.2326  0.2447  0.0121  1234.0  1300.0    66
# XGBoost Default (Lag Only)      0.2500  0.2600  0.0100  1400.0  1450.0    50
# XGBoost Tuned (All Features)    0.1925  0.2000  0.0075  1100.0  1150.0    50
#
#                                   RMSE                   R2
#                                    Val    Test Δ RMSE   Val  Test  Δ R2
# Model
# ARIMAX (All Features)           2100.0  2200.0    100  0.75  0.73 -0.02
# Random Walk (Lag Only)          2300.0  2400.0    100  0.70  0.68 -0.02
# XGBoost Default (All Features)  1800.0  1850.0     50  0.85  0.83 -0.02
# XGBoost Default (Lag Only)      2000.0  2100.0    100  0.80  0.78 -0.02
# XGBoost Tuned (All Features)    1600.0  1650.0     50  0.88  0.87 -0.01
